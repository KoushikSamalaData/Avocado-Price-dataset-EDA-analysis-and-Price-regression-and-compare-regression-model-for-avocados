# %% [markdown]
# ### Avacado Prices data set EDA analysis

# %%
#import the packages
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot  as plt

#Import warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Creating Data Frames

# %% [markdown]
# #### Form List of dictionaries constructed row by row

# %%
list_of_dicts=[{"name":"john","breed":"Dachshund","Height-cm":5.6,"weight-kg":65,"date_of_birth":"1970-10-03"},
               {"name":"scott","breed":"Dalamaite","Height-cm":4.6,"weight-kg":45,"date_of_birth":"1987-10-15"},
              ]
list_of_dicts
# Out:
# [{'name': 'john',
#   'breed': 'Dachshund',
#   'Height-cm': 5.6,
#   'weight-kg': 65,
#   'date_of_birth': '1970-10-03'},
#  {'name': 'scott',
#   'breed': 'Dalamaite',
#   'Height-cm': 4.6,
#   'weight-kg': 45,
#   'date_of_birth': '1987-10-15'}]

# %%
pd.DataFrame(list_of_dicts)
# Out:
#     name      breed  Height-cm  weight-kg date_of_birth
# 0   john  Dachshund        5.6         65    1970-10-03
# 1  scott  Dalamaite        4.6         45    1987-10-15

# %% [markdown]
# ### Form List of dictionaries constructed column by column

# %%
dict_of_lists={"name":["john","scott"],
                "breed":["Dachshund","Dalamaite"],
                "Height-cm":[5.6,4.6],
                "weight":[65,45],
            "date_of_birth":["1970-10-03","1987-10-15"],}
dict_of_lists
# Out:
# {'name': ['john', 'scott'],
#  'breed': ['Dachshund', 'Dalamaite'],
#  'Height-cm': [5.6, 4.6],
#  'weight': [65, 45],
#  'date_of_birth': ['1970-10-03', '1987-10-15']}

# %%
pd.DataFrame(dict_of_lists)
# Out:
#     name      breed  Height-cm  weight date_of_birth
# 0   john  Dachshund        5.6      65    1970-10-03
# 1  scott  Dalamaite        4.6      45    1987-10-15

# %%
 #Read the data set

avacado=pd.read_csv(r"C:\Users\samal\Documents\june24th\24th\RESUME PROJECT -- PRICE PREDICTION\avocado.csv")

#print first few rows
avacado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %% [markdown]
# ### Read CSV and assign index

# %% [markdown]
# we can assign columns as index using "index_col" attribute.
#
# we want to index Date there is another helpful function called "parse_dates" which will parse the date in the rows such that we can perform more complex subsetting(eg monthly, weekly etc).

# %%
#read the CSV using pandas and assign  date as index of dataframe

avacado=pd.read_csv(r"C:\Users\samal\Documents\june24th\24th\RESUME PROJECT -- PRICE PREDICTION\avocado.csv",parse_dates=True,index_col='Date')

#print first few rows
avacado.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# ...

# %% [markdown]
# ### Remove the index from data frame
#
# To reset the index use this function

# %%
avacado=avacado.reset_index(drop=True)
avacado
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %% [markdown]
# ### To write a CSV file function dataframe.to_csv(FILE_NAME)

# %%
avacado.to_csv("test_write.csv")

# %% [markdown]
# ### Some useful pandas function
#
# head() or .head(x) is used to get the first x rows of the DataFrame (x = 5 by default)

# %%
avacado=pd.read_csv(r"C:\Users\samal\Documents\june24th\24th\RESUME PROJECT -- PRICE PREDICTION\avocado.csv")

# %%
avacado.head(7)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6  2015-11-15          0.99      83453.76  1368.92   73672.72
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# ...

# %% [markdown]
# tail() or .tail(x) is used to get the last x rows of the DataFrame (x = 5 by default)

# %%
avacado.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %% [markdown]
# info() is used to get a concise summary of the DataFrame

# %%
avacado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# shape is used to get the dimensions of the DataFrame

# %%
avacado.shape
# Out:
# (18249, 14)

# %% [markdown]
# describe() is used find out the basis statistical values mean,std,min, max, percentile of DataFrame

# %%
avacado.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# values this attribute return a Numpy representation of the given DataFrame

# %%
avacado.values
# Out:
# array([[0, '2015-12-27', 1.33, ..., 'conventional', 2015, 'Albany'],
#        [1, '2015-12-20', 1.35, ..., 'conventional', 2015, 'Albany'],
#        [2, '2015-12-13', 0.93, ..., 'conventional', 2015, 'Albany'],
#        ...,
#        [9, '2018-01-21', 1.87, ..., 'organic', 2018, 'WestTexNewMexico'],
#        [10, '2018-01-14', 1.93, ..., 'organic', 2018, 'WestTexNewMexico'],
#        [11, '2018-01-07', 1.62, ..., 'organic', 2018, 'WestTexNewMexico']],
#       dtype=object)

# %%
avacado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# ### Appending Concatnating Series

# %%
even = pd.Series([2,4,6,8,10])
odd = pd.Series([1,3,5,7,9])

res = pd.concat([even,odd], ignore_index =True)
res
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 5     1
# 6     3
# 7     5
# 8     7
# 9     9
# dtype: int64

# %% [markdown]
# ### Sorting

# %%
# sort the values based on "Averageprice" [ascending] and year "[descending]"

avacado.sort_values(['AveragePrice','year'],ascending=[True,False])
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 15261          43  2017-03-05          0.44      64057.04      223.84
# 7412           47  2017-02-05          0.46    2200550.27  1200632.86
# 15473          43  2017-03-05          0.48      50890.73      717.57
# 15262          44  2017-02-26          0.49      44024.03      252.79
# 1716            0  2015-12-27          0.49    1137707.43   738314.80
# ...           ...         ...           ...           ...         ...
# 16720          18  2017-08-27          3.04      12656.32      419.06
# 16055          42  2017-03-12          3.05       2068.26     1043.83
# 14124           7  2016-11-06          3.12      19043.80     5898.49
# 17428          37  2017-04-16          3.17       3018.56     1255.55
# 14125           8  2016-10-30          3.25      16700.94     2325.93
#
#             4225      4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %% [markdown]
# ### Subsetting

# %%
avacado['AveragePrice']
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %% [markdown]
# ### subsetting multiple coloumns

# %%
avacado[['AveragePrice','Date']]
# Out:
#        AveragePrice        Date
# 0              1.33  2015-12-27
# 1              1.35  2015-12-20
# 2              0.93  2015-12-13
# 3              1.08  2015-12-06
# 4              1.28  2015-11-29
# ...             ...         ...
# 18244          1.63  2018-02-04
# 18245          1.71  2018-01-28
# 18246          1.87  2018-01-21
# 18247          1.93  2018-01-14
# 18248          1.62  2018-01-07
#
# [18249 rows x 2 columns]

# %%
#subsettig rows
# This print only the rows with price less than 1
avacado[avacado['AveragePrice']<1]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume      4046  \
# 2               2  2015-12-13          0.93     118220.22    794.70
# 6               6  2015-11-15          0.99      83453.76   1368.92
# 7               7  2015-11-08          0.98     109428.33    703.75
# 13             13  2015-09-27          0.99     106803.39   1204.88
# 43             43  2015-03-01          0.99      55595.74    629.46
# ...           ...         ...           ...           ...       ...
# 17169          43  2017-03-05          0.99     155011.12  35367.23
# 17170          44  2017-02-26          0.99     171145.00  34520.03
# 17536          39  2017-04-02          0.98     402676.23  34093.33
# 17537          40  2017-03-26          0.90     456645.91  36169.35
# 17540          43  2017-03-05          0.99     367519.17  61166.48
#
#             4225    4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 2      109149.67  130.50     8145.35     8042.21      103.14          0.0
# ...

# %% [markdown]
# ### Subsetting based on text data

# %%
avacado[avacado["type"]=="organic"]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 9126            0  2015-12-27          1.83        989.55     8.16    88.59
# 9127            1  2015-12-20          1.89       1163.03    30.24   172.14
# 9128            2  2015-12-13          1.85        995.96    10.44   178.70
# 9129            3  2015-12-06          1.84       1158.42    90.29   104.18
# 9130            4  2015-11-29          1.94        831.69     0.00    94.73
# ...           ...         ...           ...           ...      ...      ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
# ...

# %% [markdown]
# ### Subsetting Based on Dates

# %%
#it willl print dates less than '2015-02-04'
avacado[avacado["Date"]<='2015-02-04']
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# 47             47  2015-02-01          0.99      70873.60  1353.90  60017.20
# 48             48  2015-01-25          1.06      45147.50   941.38  33196.16
# 49             49  2015-01-18          1.17      44511.28   914.14  31540.32
# 50             50  2015-01-11          1.24      41195.08  1002.85  31640.34
# 51             51  2015-01-04          1.22      40873.28  2819.50  28287.42
# ...           ...         ...           ...           ...      ...       ...
# 11928          46  2015-02-01          1.77       7210.19  1634.42   3012.44
# 11929          47  2015-01-25          1.63       7324.06  1934.46   3032.72
# 11930          48  2015-01-18          1.71       5508.20  1793.64   2078.72
# 11931          49  2015-01-11          1.69       6861.73  1822.28   2377.54
# 11932          50  2015-01-04          1.64       6182.81  1561.30   2958.17
#
# ...

# %% [markdown]
# ### Subsetting based on multiple conditions
#
# #### You can use the logical operators to define a complex condition
#
# "&" and
#
# "|" or
#
# "~" not

# %%
avacado[(avacado["Date"]<"2015-02-04") & (avacado["type"]=="organic")]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 9173           47  2015-02-01          1.83       1228.51    33.12    99.36
# 9174           48  2015-01-25          1.89       1115.89    14.87   148.72
# 9175           49  2015-01-18          1.93       1118.47     8.02   178.78
# 9176           50  2015-01-11          1.77       1182.56    39.00   305.12
# 9177           51  2015-01-04          1.79       1373.95    57.42   153.88
# ...           ...         ...           ...           ...      ...      ...
# 11928          46  2015-02-01          1.77       7210.19  1634.42  3012.44
# 11929          47  2015-01-25          1.63       7324.06  1934.46  3032.72
# 11930          48  2015-01-18          1.71       5508.20  1793.64  2078.72
# 11931          49  2015-01-11          1.69       6861.73  1822.28  2377.54
# 11932          50  2015-01-04          1.64       6182.81  1561.30  2958.17
#
# ...

# %% [markdown]
# ### Subsetting using .isin()

# %% [markdown]
# #### isin() method helps in selecting rows with having a particular(or Multiple) value in a particular column
#
#
# Syntax: DataFrame.isin(values)
#
#
# Parameters: values: iterable, Series, List, Tuple, DataFrame or dictionary to check in the caller Series/Data Frame.
#
#
# Return Type: DataFrame of Boolean of Dimension.

# %%
#subset avacado in region "boston" or "sandiego"
regionfilter=avacado["region"].isin(["Boston","SanDiego"])
avacado[regionfilter]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 208             0  2015-12-27          1.13     450816.39  3886.27  346964.70
# 209             1  2015-12-20          1.07     489802.88  4912.37  390100.99
# 210             2  2015-12-13          1.01     549945.76  4641.02  455362.38
# 211             3  2015-12-06          1.02     488679.31  5126.32  407520.22
# 212             4  2015-11-29          1.19     350559.81  3609.25  272719.08
# ...           ...         ...           ...           ...      ...        ...
# 18100           7  2018-02-04          1.81      17454.74  1158.41    7388.27
# 18101           8  2018-01-28          1.91      17579.47  1145.64    8284.41
# 18102           9  2018-01-21          1.95      18676.37  1088.49    9282.37
# 18103          10  2018-01-14          1.81      21770.02  3285.98   14338.52
# 18104          11  2018-01-07          2.06      16746.82  5150.82    9366.31
#
# ...

# %% [markdown]
# ### Multiple parameter Filtering
#
# Use logical operators to combine different filters

# %%
avacado=pd.read_csv(r"C:\Users\samal\Documents\june24th\24th\RESUME PROJECT -- PRICE PREDICTION\avocado.csv")
avacado
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
# subset the avocado in the region Boston or SanDiego in the year 2016 or 2017
regionFilter = avacado["region"].isin(["Boston", "SanDiego"])
yearFilter = avacado["year"].isin([2016, 2017])
avacado[regionFilter & yearFilter]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 3016            0  2016-12-25          1.28     447600.75  4349.63  346516.32
# 3017            1  2016-12-18          1.09     579577.33  6123.84  488107.01
# 3018            2  2016-12-11          1.22     510800.58  3711.20  409645.98
# 3019            3  2016-12-04          1.26     473428.36  4371.95  393748.18
# 3020            4  2016-11-27          1.45     391257.01  4243.20  317090.39
# ...           ...         ...           ...           ...      ...        ...
# 16962          48  2017-01-29          1.21      18191.46  1477.75    8949.53
# 16963          49  2017-01-22          1.73      10842.77  2019.23    6869.87
# 16964          50  2017-01-15          1.82      11578.42  2529.20    7637.66
# 16965          51  2017-01-08          1.52      16775.97  2363.28    9429.06
# 16966          52  2017-01-01          1.45      15752.25  1385.18    8618.28
#
# ...

# %% [markdown]
# ### Multiple parameter Filtering
#
# Use logical operators to combine different filters

# %% [markdown]
# ### Detecting missing values .isna()
#
# isna() is a method used to find is there exist any NaN values in the DataFrame
#
# It will give a True bool value if a cell has a NaN value

# %%
avacado.isna()
# Out:
#        Unnamed: 0   Date  AveragePrice  Total Volume   4046   4225   4770  \
# 0           False  False         False         False  False  False  False
# 1           False  False         False         False  False  False  False
# 2           False  False         False         False  False  False  False
# 3           False  False         False         False  False  False  False
# 4           False  False         False         False  False  False  False
# ...           ...    ...           ...           ...    ...    ...    ...
# 18244       False  False         False         False  False  False  False
# 18245       False  False         False         False  False  False  False
# 18246       False  False         False         False  False  False  False
# 18247       False  False         False         False  False  False  False
# 18248       False  False         False         False  False  False  False
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags   type   year  region
# ...

# %% [markdown]
# ### we can use any function to concise info

# %%
avacado.isna().any()
# Out:
# Unnamed: 0      False
# Date            False
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type            False
# year            False
# region          False
# dtype: bool

# %% [markdown]
# ### Counting missing values

# %%
avacado.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# ### Remove missing values

# %%
avacado.dropna()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
meanVal = avacado["AveragePrice"].mean()
avacado.fillna(meanVal)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# above both displays same dataset

# %% [markdown]
# ### Adding a new column
#
# It can easily be done using the [ ] brackets
#
# Lets add a new column to our dataframe called AveragePricePer100

# %%
avacado["AveragePrice100"]=avacado["AveragePrice"]*100
avacado
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# ### Deleting columns in DataFrame .drop(lst,axis = 1)
#
# dataFrame.drop(['COLUMN_NAME'], axis = 1)
#
#
# the first parameter is a list of columns to be deleted
#
# axis = 1 means delete column
#
# axis = 0 means delete row

# %%
avacado.drop(["AveragePrice100"],axis=1)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# ### Summary statistics
#
# Some of the functions availabe in pandas are:
#
# median() mode() min() max() var() std() sum() quantile()

# %%
#mean of average price
avacado['AveragePrice'].mean()
# Out:
# 1.405978409775878

# %% [markdown]
# ### Summarizing dates
#
# To find the min or max date in a dataframe

# %%
avacado["Date"].max()
# Out:
# '2018-03-25'

# %% [markdown]
# ### agg() method
#
# Pandas Series.agg() is used to pass a function or list of function to be applied on a series or even each element of series separately.
#
# Syntax: Series.agg(func, axis=0)
#
# Parameters: func: Function, list of function or string of function name to be called on Series. axis:0 or ‘index’ for row wise operation and 1 or ‘columns’ for column wise operation.
#
# Return Type: The return type depends on return type of function passed as parameter.

# %%
def pct30(column):
    return column.quantile(0.3)
def pct50(column):
    return column.quantile(0.5)  
avacado[["AveragePrice","Total Bags"]].agg([pct30,pct50])
# Out:
#        AveragePrice  Total Bags
# pct30          1.15    7316.634
# pct50          1.37   39743.830

# %% [markdown]
# <a id="Dropping-duplicate-names"></a>
# ## Dropping duplicate names .drop_duplicates(lst)
# Delete all the duplicate names from the dataframe

# %%
temp=avacado.drop_duplicates(subset=['year'])
temp
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0              0  2015-12-27          1.33      64236.62   1036.74   54454.85
# 2808           0  2016-12-25          1.52      73341.73   3202.39   58280.33
# 5616           0  2017-12-31          1.47     113514.42   2622.70  101135.53
# 8478           0  2018-03-25          1.57     149396.50  16361.69  109045.03
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0      48.16     8696.87     8603.62       93.25         0.00  conventional
# 2808  426.92    11432.09    11017.32      411.83         2.94  conventional
# 5616   20.25     9735.94     5556.98     4178.96         0.00  conventional
# 8478   65.45    23924.33    19273.80     4270.53       380.00  conventional
#
#       year  region  AveragePrice100
# 0     2015  Albany            133.0
# 2808  2016  Albany            152.0
# 5616  2017  Albany            147.0
# 8478  2018  Albany            157.0

# %% [markdown]
# ### Count categorical data .value_counts()
#
# Pandas Series.value_counts() function return a Series containing counts of unique values.

# %%
avacado["year"].value_counts(sort=True,ascending= False)
# Out:
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: count, dtype: int64

# %% [markdown]
# ### Grouped summaries .groupby(col)
#
# This function will group similar categories into one and then we can perform some summary statistics
#
# Syntax: DataFrame.groupby(by=None, axis=0, level=None, as_index=True, sort=True, group_keys=True, squeeze=False, **kwargs)

# %%
#Group by multiple columns and perform multiple operations
avacado.groupby(["year","type"])["AveragePrice"].agg([min,max,np.mean,np.median])
# Out:
#                     min   max      mean  median
# year type
# 2015 conventional  0.49  1.59  1.077963    1.08
#      organic       0.81  2.79  1.673324    1.67
# 2016 conventional  0.51  2.20  1.105595    1.08
#      organic       0.58  3.25  1.571684    1.53
# 2017 conventional  0.46  2.22  1.294888    1.30
#      organic       0.44  3.17  1.735521    1.72
# 2018 conventional  0.56  1.74  1.127886    1.14
#      organic       1.01  2.30  1.567176    1.55

# %% [markdown]
# ### Pivot table
#
# A pivot table is a table of statistics that summarizes the data of a more extensive table.
#
# IMPORRANT parements to remember are
# "index": it is the value that appeares on the left most side of the table (it can be a list)
# "columns": these are the column you want to add to the pivot table
# "aggfunc": it will call the function (it can be a list)
# "values": it is the attribute which will be summarized in the table (values inside the table)
#
# Syntax
#
# pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc=’mean’, fill_value=None, margins=False, dropna=True, margins_name=’All’)#

# %%
#This is same as we build in previous table but  using pivot table here
avacado.pivot_table(index=["year","type"],aggfunc=[min,max,np.mean,np.median],values= "AveragePrice" )
# Out:
#                            min          max         mean       median
#                   AveragePrice AveragePrice AveragePrice AveragePrice
# year type
# 2015 conventional         0.49         1.59     1.077963         1.08
#      organic              0.81         2.79     1.673324         1.67
# 2016 conventional         0.51         2.20     1.105595         1.08
#      organic              0.58         3.25     1.571684         1.53
# 2017 conventional         0.46         2.22     1.294888         1.30
#      organic              0.44         3.17     1.735521         1.72
# 2018 conventional         0.56         1.74     1.127886         1.14
#      organic              1.01         2.30     1.567176         1.55

# %% [markdown]
# <a id="Explicit-indexes"></a>
# ## Explicit indexes
# Indexes make subsetting simpler using .loc and .iloc

# %%
# Setting Column as index
regionIndex=avacado.set_index(['region'])
regionIndex
# Out:
#                   Unnamed: 0        Date  AveragePrice  Total Volume     4046  \
# region
# Albany                     0  2015-12-27          1.33      64236.62  1036.74
# Albany                     1  2015-12-20          1.35      54876.98   674.28
# Albany                     2  2015-12-13          0.93     118220.22   794.70
# Albany                     3  2015-12-06          1.08      78992.15  1132.00
# Albany                     4  2015-11-29          1.28      51039.60   941.48
# ...                      ...         ...           ...           ...      ...
# WestTexNewMexico           7  2018-02-04          1.63      17074.83  2046.96
# WestTexNewMexico           8  2018-01-28          1.71      13888.04  1191.70
# WestTexNewMexico           9  2018-01-21          1.87      13766.76  1191.92
# WestTexNewMexico          10  2018-01-14          1.93      16205.22  1527.63
# WestTexNewMexico          11  2018-01-07          1.62      17489.58  2894.77
#
# ...

# %%
#same can display using below code
avacado[avacado['region'].isin(["Albany", "WestTexNewMexico"])]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
#we can do simply by
regionIndex.loc[["Albany", "WestTexNewMexico"]]
# Out:
#                   Unnamed: 0        Date  AveragePrice  Total Volume     4046  \
# region
# Albany                     0  2015-12-27          1.33      64236.62  1036.74
# Albany                     1  2015-12-20          1.35      54876.98   674.28
# Albany                     2  2015-12-13          0.93     118220.22   794.70
# Albany                     3  2015-12-06          1.08      78992.15  1132.00
# Albany                     4  2015-11-29          1.28      51039.60   941.48
# ...                      ...         ...           ...           ...      ...
# WestTexNewMexico           7  2018-02-04          1.63      17074.83  2046.96
# WestTexNewMexico           8  2018-01-28          1.71      13888.04  1191.70
# WestTexNewMexico           9  2018-01-21          1.87      13766.76  1191.92
# WestTexNewMexico          10  2018-01-14          1.93      16205.22  1527.63
# WestTexNewMexico          11  2018-01-07          1.62      17489.58  2894.77
#
# ...

# %% [markdown]
# ### Visulaizing the data
#
# Histograms
#
# using hist function

# %%
#histogram
avacado.hist(["AveragePrice"],bins=10)
plt.show()

# %%
sns.countplot(x='year',data=avacado,hue='type');
plt.show()

# %% [markdown]
# ### Bar plots

# %%
regionFilter=avacado.groupby('region')["AveragePrice"].mean().head(10)
regionFilter
# Out:
# region
# Albany                 1.561036
# Atlanta                1.337959
# BaltimoreWashington    1.534231
# Boise                  1.348136
# Boston                 1.530888
# BuffaloRochester       1.516834
# California             1.395325
# Charlotte              1.606036
# Chicago                1.556775
# CincinnatiDayton       1.209201
# Name: AveragePrice, dtype: float64

# %%
regionFilter.plot(kind='bar',rot=45,title="AveragePrice in 10 regions")
# Out:
# <Axes: title={'center': 'AveragePrice in 10 regions'}, xlabel='region'>

# %% [markdown]
# ### Scatter plot

# %%
avacado.plot(x="AveragePrice", y="Total Volume", kind="scatter")
# Out:
# <Axes: xlabel='AveragePrice', ylabel='Total Volume'>

# %%
avacado.year=avacado.year.apply(str)
sns.boxenplot(x="year", y="AveragePrice", data=avacado)

# %%
vis1=sns.lmplot(data=avacado, x='year',y='AveragePrice',fit_reg=False,hue='region')

# %%
g=sns.FacetGrid(data=avacado,row='region',col='year',hue='region')
g=g.map(plt.hist,'AveragePrice')
